# %%
import requests
import os

HUGGING_FACE_TOKEN = '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'
headers = {"Authorization": f"Bearer {HUGGING_FACE_TOKEN}"}
API_URL = "https://datasets-server.huggingface.co/first-rows?dataset=bookcorpus&config=plain_text&split=validation"

# %%
def query():
    response = requests.request("GET", API_URL, headers=headers)
    return response.json()
data = query()

# %%
import json
json_formatted_str = json.dumps(data, indent=2)
print(json_formatted_str)
# Out:
# {
#   "dataset": "bookcorpus",
#   "config": "plain_text",
#   "split": "train",
#   "features": [
#     {
#       "feature_idx": 0,
#       "name": "text",
#       "type": {
#         "dtype": "string",
#         "_type": "Value"
#       }
#     }
#   ],
#   "rows": [
#     {
#       "row_idx": 0,
#       "row": {
#         "text": "usually , he would be tearing around the living room , playing with his toys ."
#       },
#       "truncated_cells": []
#     },
#     {
#       "row_idx": 1,
#       "row": {
#         "text": "but just one look at a minion sent him practically catatonic ."
#       },
#       "truncated_cells": []
#     },
#     {
#       "row_idx": 2,
#       "row": {
#         "text": "that had been megan 's plan when she got him dressed earlier ."
#       },
#       "truncated_cells": []
#     },
#     {
#       "row_idx": 3,
#       "row": {
# ...

# %%
len(data["rows"])
# Out:
# 100

# %%
with open("bert_testset.testcase", "w") as f:
    image_urls = [row["row"]["image"]["src"] + "\n" for row in data["rows"]]
    f.writelines(image_urls)

# %%
with open("bert_testset.label", "w") as f:
    label_index = [label for label in data["features"][1]["type"]["names"]]
    labels = [label_index[row["row"]["label"]] + "\n" for row in data["rows"]]
    f.writelines(labels)
